# %%
import pandas as pd 

from porise.model.algorithms.cmab import BayesianHybridLinUCBPER
from porise.envs.real import ChainOfferEnvV2
from porise import Simulator

# %%
df = pd.read_csv('../porise/data/exp5217_all_imp100_scaled_train_new.csv')
print("cdna user features loaded")
df = df.set_index('easy_id')
user_map = df.T.to_dict('list')
print('get user map ready')
# Out:
# cdna user features loaded
# get user map ready

# %%
# env = RealEnv(rat_log_path='../porise/data/reward_nov02_nov30_exp5217.csv', user_vectors_map=user_map)
env = ChainOfferEnvV2(rat_log_path='../porise/data/sampled_rat_log_exp5217.csv', user_vectors_map=user_map)

# %%
model = BayesianHybridLinUCBPER(
    n_arms=env.n_arms,
    alpha=2,
    arm_feat_dim=env.arm_feat_dim,
    user_feat_dim=env.user_feat_dim,
    return_list=False,
    memory_size=int(1e4),
    prio_a=0.6,
    prio_beta=0.4,
    prio_e=0.001,
    beta_increment_per_sampling=0.4e-6,
    batch_size=128,
    epochs=10,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-438c5bd8da31> in <module>
# ----> 1 model = HybridLinUCBPER(
#       2     n_arms=env.n_arms,
#       3     alpha=2,
#       4     arm_feat_dim=env.arm_feat_dim,
#       5     user_feat_dim=env.user_feat_dim,
#
# NameError: name 'HybridLinUCBPER' is not defined

# %%
simulator = Simulator(model=model,
                     env=env,
                     train_every=int(128),
                     throttle=int(1e2),
                     memory_capacity=int(128),
                     plot_every=int(1e4))
simulator.run()

# %% [markdown]
# ### Train with past N records, every time a new record comes.

# %%
simulator = Simulator(model=model,
                     env=env,
                     train_every=int(128),
                     throttle=int(1e2),
                     memory_capacity=int(128),
                     plot_every=int(1e4))
simulator.run()
# Out:
# 384600it [45:01, 142.36it/s, total reward=5806.0]

# %%
model = HybridLinUCBPER(
    n_arms=env.action_space.n,
    alpha=2,
    arm_feat_dim=len(env.get_user_state()[1][0]),
    user_feat_dim=len(env.get_user_state()[0]),
    return_list=False,
    memory_size=int(2e4),
    prio_a=0.6,
    prio_beta=0.4,
    prio_e=0.001,
    beta_increment_per_sampling=0.4e-6,
    batch_size=128,
    epochs=10,
)

simulator = Simulator(model=model,
                     env=env,
                     train_every=int(128),
                     throttle=int(1e2),
                     memory_capacity=int(128),
                     plot_every=int(1e4))
simulator.run()
# Out:
# 384600it [47:28, 135.03it/s, total reward=5843.0]
