# %%
import pandas as pd 

from porise.model.algorithms.cmab import LogisticTS
from porise.envs.real import ChainOfferEnv
from porise import Simulator

# %%
df = pd.read_csv('../porise/data/exp5217_all_imp100_scaled_train_new.csv')
print("cdna user features loaded")
df = df.set_index('easy_id')
user_map = df.T.to_dict('list')
print('get user map ready')
# Out:
# cdna user features loaded
# get user map ready

# %%
env = ChainOfferEnv(rat_log_path='../porise/data/sampled_rat_log_exp5217.csv', user_vectors_map=user_map)

# %% [markdown]
# ### Test LogTS2

# %%
model = LogisticTS(n_arms=env.n_arms,
                  lambda_=1, # exploitation
                  alpha=10, # exploration, very important for performance
                  arm_feat_dim=env.arm_feat_dim,
                  user_feat_dim=env.user_feat_dim,
                  return_list=False)

simulator = Simulator(model=model,
                     env=env,
                     train_every=int(128),
                     throttle=int(1e2),
                     memory_capacity=int(128),
                     plot_every=int(1e4))

# %%
simulator.run()
# Out:
#  99%|█████████▉| 381200/384588 [23:32<00:13, 253.85it/s, total reward=3495.0]/Users/xiaolan.a.jiang/Library/Python/3.8/lib/python/site-packages/porise/model/algorithms/cmab/logistic_ts.py:43: RuntimeWarning: overflow encountered in exp
#   proba = 1 / (1 + np.exp(-1 * X.dot(w)))
# 384600it [23:45, 269.87it/s, total reward=3521.0]

# %%
model = LogisticTS2(n_arms=env.action_space.n,
                  lambda_=1, # exploitation
                  alpha=15, # exploration, very important for performance
                  arm_feat_dim=len(env.get_user_state()[1][0]),
                  user_feat_dim=len(env.get_user_state()[0]),
                  return_list=False)

simulator = Simulator(model=model,
                     env=env,
                     train_every=int(128),
                     throttle=int(1e2),
                     memory_capacity=int(128),
                     plot_every=int(1e4))

simulator.run()
# Out:
#  99%|█████████▉| 380200/384588 [25:28<00:15, 282.98it/s, total reward=2013.0]/Users/xiaolan.a.jiang/Library/Python/3.8/lib/python/site-packages/porise/model/algorithms/cmab/logistic_ts.py:43: RuntimeWarning: overflow encountered in exp
#   proba = 1 / (1 + np.exp(-1 * X.dot(w)))
# 384600it [25:39, 249.76it/s, total reward=2036.0]
