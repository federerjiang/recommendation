# %%
import pandas as pd

# %%
df = pd.read_csv('exp5217_all_imp100_scaled_train_new.csv')
print("cdna user features loaded")
df = df.set_index('easy_id')
# Out:
# cdna user features loaded

# %%
df.head()
# Out:
#    beauty_l6m_time_spent_in_seconds  has_pet_cat_prob  \
# 0                         -5.199338          0.554991
# 1                         -5.199338          0.925761
# 2                         -5.199338         -0.459938
# 3                         -5.199338          1.893739
# 4                         -5.199338         -0.522423
#
#    beauty_l3m_time_spent_in_seconds  interest_in_books_cd  \
# 0                         -5.199338              0.465405
# 1                         -5.199338             -5.199338
# 2                         -5.199338             -5.199338
# 3                         -5.199338              1.337127
# 4                         -5.199338              0.764710
#
#    beauty_ly_time_spent_in_seconds  pointclub_lifetime_time_spent_in_seconds  \
# 0                        -5.199338                                 -0.247134
# 1                        -5.199338                                  1.168656
# ...

# %%
df_cdna_sample = df.sample(n=5)

# %%
df_cdna_sample.head(10)
# Out:
#         beauty_l6m_time_spent_in_seconds  has_pet_cat_prob  \
# 107875                         -5.199338          0.073302
# 326721                         -5.199338          0.834968
# 207668                          2.031967          0.910544
# 102285                         -5.199338         -0.128631
# 25230                          -5.199338          0.352893
#
#         beauty_l3m_time_spent_in_seconds  interest_in_books_cd  \
# 107875                         -5.199338             -5.199338
# 326721                         -5.199338             -5.199338
# 207668                          2.067613              1.602210
# 102285                         -5.199338              0.465405
# 25230                          -5.199338             -5.199338
#
#         beauty_ly_time_spent_in_seconds  \
# 107875                        -5.199338
# 326721                        -5.199338
# 207668                         2.472442
# 102285                        -5.199338
# ...
